# %% [markdown]
# Decision Tree
#
# Tiatnic Survival Dataset

# %% [markdown]
# # Import the Necessary Libraries

# %%
import pandas as pd
df=pd.read_csv('train.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Load the data sets- train and test

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# # Look at top values of train data

# %%
import pandas as pd

# Load the train dataset
df = pd.read_csv('train.csv')

# Display the top values of the train dataset
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Print the column names of train data

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # Print the dimension of train and test data

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # Print the number of missing values in each column of train and test data

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# # Barchart of Survived, Pclass, Sex, Embarked

# %%
import matplotlib.pyplot as plt

# Create a list of the columns to plot
columns_to_plot = ['Survived', 'Pclass', 'Sex', 'Embarked']

# Plot bar charts for each column
plt.figure(figsize=(12, 8))

for i, column in enumerate(columns_to_plot, 1):
    plt.subplot(2, 2, i)  # 2 rows, 2 columns, subplot index
    df[column].value_counts().plot(kind='bar', color='skyblue')
    plt.title(f'Bar chart of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Histogram of Age, Parch, Fare

# %%
# Plot histograms for Age, Parch, and Fare
plt.figure(figsize=(12, 8))

# Create histogram for Age
plt.subplot(1, 3, 1)
df['Age'].dropna().plot(kind='hist', bins=30, color='lightgreen', edgecolor='black')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')

# Create histogram for Parch
plt.subplot(1, 3, 2)
df['Parch'].plot(kind='hist', bins=10, color='lightcoral', edgecolor='black')
plt.title('Histogram of Parch')
plt.xlabel('Parch')
plt.ylabel('Frequency')

# Create histogram for Fare
plt.subplot(1, 3, 3)
df['Fare'].plot(kind='hist', bins=30, color='lightblue', edgecolor='black')
plt.title('Histogram of Fare')
plt.xlabel('Fare')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Plot histograms for Age, Parch, and Fare in the same figure
plt.figure(figsize=(10, 6))

# Plot histograms for each column with different colors and transparency
df['Age'].dropna().plot(kind='hist', bins=30, alpha=0.5, label='Age', color='lightgreen', edgecolor='black')
df['Parch'].plot(kind='hist', bins=10, alpha=0.5, label='Parch', color='lightcoral', edgecolor='black')
df['Fare'].plot(kind='hist', bins=30, alpha=0.5, label='Fare', color='lightblue', edgecolor='black')

# Adding titles and labels
plt.title('Histograms of Age, Parch, and Fare')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Display legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Plot histogram of age for survived and did not survived class

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Example: Loading a CSV file
train_df = pd.read_csv('train.csv')

# Create a histogram of Age for Survived (1) and Not Survived (0) classes
plt.figure(figsize=(10, 6))

# Histogram for passengers who did not survive
train_df[train_df['Survived'] == 0]['Age'].dropna().plot(kind='hist', bins=30, alpha=0.5, color='red', label='Not Survived', edgecolor='black')

# Histogram for passengers who survived
train_df[train_df['Survived'] == 1]['Age'].dropna().plot(kind='hist', bins=30, alpha=0.5, color='green', label='Survived', edgecolor='black')

# Adding titles and labels
plt.title('Histogram of Age for Survived and Not Survived')
plt.xlabel('Age')
plt.ylabel('Frequency')

# Display legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Count class and geder wise survival rate - plot with appropriate chart
# # Age wise Distribution of Male and Female passengers

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate survival rate by class and gender
survival_rates = train_df.groupby(['Pclass', 'Sex'])['Survived'].mean().unstack()

# Plot a grouped bar chart
survival_rates.plot(kind='bar', figsize=(10, 6), color=['lightblue', 'lightcoral'])

# Add labels and title
plt.title('Survival Rate by Class and Gender')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.xticks(rotation=0)
plt.legend(title='Gender')

# Show the plot
plt.show()

# %%
 import seaborn as sns
import matplotlib.pyplot as plt

# Plot the age distribution for male and female passengers
plt.figure(figsize=(10, 6))
sns.kdeplot(train_df[train_df['Sex'] == 'male']['Age'].dropna(), label='Male', fill=True, color='blue')
sns.kdeplot(train_df[train_df['Sex'] == 'female']['Age'].dropna(), label='Female', fill=True, color='pink')

# Add labels and title
plt.title('Age-wise Distribution of Male and Female Passengers')
plt.xlabel('Age')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()
# Out:
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Histogram of Age of the given data set(sample)

# %%
import matplotlib.pyplot as plt
import numpy as np
# Replace infinite values with NaN and drop missing Age values
train_df['Age'].replace([np.inf, -np.inf], np.nan, inplace=True)
train_df = train_df.dropna(subset=['Age'])

# Plot the histogram
plt.figure(figsize=(10, 6))
plt.hist(train_df['Age'], bins=30, color='skyblue', edgecolor='black', alpha=0.7)

# Add labels and title
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ## Handling Missing Values

# %% [markdown]
# # Replace the msiing values in Embarked column by 'S'

# %%
# Replace missing values in the 'Embarked' column with 'S'
train_df['Embarked'].fillna('S', inplace=True)

# Verify if there are any missing values left in 'Embarked'
print(train_df['Embarked'].isnull().sum())  # Should print 0
# Out:
# 0

# %% [markdown]
# # Impute the missing values in Fare column with median value

# %%
# Replace missing values in the 'Fare' column with the median value
train_df['Fare'].fillna(train_df['Fare'].median(), inplace=True)

# Verify if there are any missing values left in 'Fare'
print(train_df['Fare'].isnull().sum())  # Should print 0
# Out:
# 0

# %% [markdown]
# # Impute the Age column. It has too many missing values but it may be important.
# # We fill the missing values with numbers randomly drawn from distribution
# # that has same mean and standard deviation as non missing Age data

# %%
import numpy as np

# Calculate the mean and standard deviation of the existing Age values
age_mean = train_df['Age'].mean()
age_std = train_df['Age'].std()

# Count missing Age values
missing_count = train_df['Age'].isnull().sum()

# Generate random values from a normal distribution with same mean & std
random_ages = np.random.normal(loc=age_mean, scale=age_std, size=missing_count)

# Ensure all generated ages are non-negative
random_ages = np.clip(random_ages, 0, None)

# Fill missing Age values with these randomly generated numbers
train_df.loc[train_df['Age'].isnull(), 'Age'] = random_ages

# Check if all missing values are filled
print("Missing Age values after imputation:", train_df['Age'].isnull().sum())  # Should print 0
# Out:
# Missing Age values after imputation: 0

# %% [markdown]
# ## Feature Engineering - Creating new features

# %% [markdown]
# # Create and add a new feature FamilySize as a combination of SibSp and Parch
# # FamilySize = Parch + SibSp + 1

# %%
# Create FamilySize feature
train_df['FamilySize'] = train_df['SibSp'] + train_df['Parch'] + 1

# Display first few rows to verify
print(train_df[['SibSp', 'Parch', 'FamilySize']].head())
# Out:
#    SibSp  Parch  FamilySize
# 0      1      0           2
# 1      1      0           2
# 2      0      0           1
# 3      1      0           2
# 4      0      0           1

# %% [markdown]
# # Create new feature IsAlone from FamilySize
# # If FamilySize == 1 then IsAlone = True else IsAlone = False

# %%
# Create IsAlone feature: True if FamilySize == 1, else False
train_df['IsAlone'] = train_df['FamilySize'] == 1

# Display first few rows to verify
print(train_df[['FamilySize', 'IsAlone']].head())
# Out:
#    FamilySize  IsAlone
# 0           2    False
# 1           2    False
# 2           1     True
# 3           2    False
# 4           1     True

# %% [markdown]
# # Create a new attribute Has_cabin using the attribue Cabin.
# # if Cabin == NaN the Has_cabin = False else Has_cabin = True

# %%
# Create Has_cabin feature: True if Cabin is not NaN, else False
train_df['Has_cabin'] = train_df['Cabin'].notna()

# Display first few rows to verify
print(train_df[['Cabin', 'Has_cabin']].head())
# Out:
#   Cabin  Has_cabin
# 0   NaN      False
# 1   C85       True
# 2   NaN      False
# 3  C123       True
# 4   NaN      False

# %% [markdown]
# # Drop the columns which may not be useful in prediction of survival
# # Drop PassengerId, Name, Ticket, and Cabin

# %%
# Drop unnecessary columns
train_df = train_df.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'])

# Display first few rows to verify
print(train_df.head())
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  FamilySize  \
# 0         0       3    male  22.0      1      0   7.2500        S           2
# 1         1       1  female  38.0      1      0  71.2833        C           2
# 2         1       3  female  26.0      0      0   7.9250        S           1
# 3         1       1  female  35.0      1      0  53.1000        S           2
# 4         0       3    male  35.0      0      0   8.0500        S           1
#
#    IsAlone  Has_cabin
# 0    False      False
# 1    False       True
# 2     True      False
# 3    False       True
# 4     True      False

# %% [markdown]
# ## Model Building

# %%
# Prepare X and y

# %%
# Define the target variable (y)
y = train_df['Survived']

# Define the feature set (X) - drop 'Survived' as it's the target
X = train_df.drop(columns=['Survived'])

# Display shapes to verify
print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")

# Display first few rows of X to confirm
print(X.head())
# Out:
# Shape of X: (714, 10)
# Shape of y: (714,)
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked  FamilySize  IsAlone  \
# 0       3    male  22.0      1      0   7.2500        S           2    False
# 1       1  female  38.0      1      0  71.2833        C           2    False
# 2       3  female  26.0      0      0   7.9250        S           1     True
# 3       1  female  35.0      1      0  53.1000        S           2    False
# 4       3    male  35.0      0      0   8.0500        S           1     True
#
#    Has_cabin
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False

# %% [markdown]
# # Label encoding of categorical features

# %%
from sklearn.preprocessing import LabelEncoder

# Identify categorical columns
categorical_cols = X.select_dtypes(include=['object']).columns

# Apply Label Encoding to each categorical column
label_encoders = {}  # Store encoders for later use (if needed)
for col in categorical_cols:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])
    label_encoders[col] = le  # Save encoder if needed for inverse transformation

# Display first few rows to verify
print(X.head())
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  FamilySize  IsAlone  \
# 0       3    1  22.0      1      0   7.2500         2           2    False
# 1       1    0  38.0      1      0  71.2833         0           2    False
# 2       3    0  26.0      0      0   7.9250         2           1     True
# 3       1    0  35.0      1      0  53.1000         2           2    False
# 4       3    1  35.0      0      0   8.0500         2           1     True
#
#    Has_cabin
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False

# %% [markdown]
# # concat df_categorical with original df

# %%
from sklearn.preprocessing import LabelEncoder

# Identify categorical columns in X
categorical_cols = X.select_dtypes(include=['object']).columns

# Apply Label Encoding and store the transformed categorical features
df_categorical = X[categorical_cols].apply(LabelEncoder().fit_transform)

# Drop original categorical columns from X and concatenate encoded ones
X = X.drop(columns=categorical_cols)
df_final = pd.concat([X, df_categorical], axis=1)

# Display first few rows to verify
print(df_final.head())
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  FamilySize  IsAlone  \
# 0       3    1  22.0      1      0   7.2500         2           2    False
# 1       1    0  38.0      1      0  71.2833         0           2    False
# 2       3    0  26.0      0      0   7.9250         2           1     True
# 3       1    0  35.0      1      0  53.1000         2           2    False
# 4       3    1  35.0      0      0   8.0500         2           1     True
#
#    Has_cabin   0
# 0      False NaN
# 1       True NaN
# 2      False NaN
# 3       True NaN
# 4      False NaN
# /tmp/ipykernel_5567/2067342467.py:11: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   df_final = pd.concat([X, df_categorical], axis=1)

# %% [markdown]
# # Do a pairplot of all features

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the train dataset
train_df = pd.read_csv('train.csv')

# Define the numerical columns for the pairplot
numerical_features = ['Age', 'SibSp', 'Parch', 'Fare', 'Survived']

# Create pairplot
sns.pairplot(train_df[numerical_features])

# Show the plot
plt.show()
# Out:
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # Splitting the data into train and validation set - 90% train 10% validation
# # X_train, X_test, y_train, y_validation

# %%
# Check the current columns in the dataframe
print(train_df.columns)

# Define the columns to drop (only those that exist)
columns_to_drop = ['Survived', 'PassengerId', 'Name', 'Ticket', 'Cabin']
columns_to_drop = [col for col in columns_to_drop if col in train_df.columns]

# Drop the columns
X = train_df.drop(columns=columns_to_drop)

# Define the target variable
y = train_df['Survived']

# Split the data into 90% train and 10% validation
from sklearn.model_selection import train_test_split
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.1, random_state=42)

# Print the shape of the resulting splits
print(f"Training set: {X_train.shape}, Validation set: {X_validation.shape}")
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Training set: (801, 7), Validation set: (90, 7)

# %% [markdown]
# # Create the model
# # Fitting the decision tree with default hyperparameters
# # Importing decision tree classifier from sklearn library

# %%
# Check the current columns in the dataframe
print(train_df.columns)

# Define the columns to drop (only those that exist)
columns_to_drop = ['Survived', 'PassengerId', 'Name', 'Ticket', 'Cabin']
columns_to_drop = [col for col in columns_to_drop if col in train_df.columns]

# Drop the columns
X = train_df.drop(columns=columns_to_drop)

# Define the target variable
y = train_df['Survived']

# Split the data into 90% train and 10% validation
from sklearn.model_selection import train_test_split
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.1, random_state=42)

# Print the shape of the resulting splits
print(f"Training set: {X_train.shape}, Validation set: {X_validation.shape}")
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Training set: (801, 7), Validation set: (90, 7)

# %% [markdown]
# # Print the tree
#
# # Importing required packages for visualization

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt

# Load the dataset
train_df = pd.read_csv('train.csv')

# Preprocessing: Label encode categorical columns and handle missing values
train_df = train_df.apply(LabelEncoder().fit_transform)  # Encode all categorical columns
X = train_df.drop(columns=['Survived', 'PassengerId', 'Name', 'Ticket', 'Cabin'])
y = train_df['Survived']

# Split into train and validation sets
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.1, random_state=42)

# Impute missing values
imputer = SimpleImputer(strategy='mean')
X_train = imputer.fit_transform(X_train)
X_validation = imputer.transform(X_validation)

# Train Decision Tree model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# Plot the tree
plt.figure(figsize=(20, 10))
plot_tree(model, feature_names=X.columns, class_names=['Not Survived', 'Survived'], filled=True, rounded=True)
plt.show()

# %% [markdown]
# # plotting tree with max_depth=3

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv('train.csv')

# Encode categorical features
for col in ['Sex', 'Embarked']:
    df[col] = LabelEncoder().fit_transform(df[col].astype(str))

# Select features and target
X = df.drop(columns=['Survived', 'PassengerId', 'Name', 'Ticket', 'Cabin'])
y = df['Survived']

# Train-test split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

# Handle missing values
X_train = SimpleImputer(strategy='mean').fit_transform(X_train)
X_val = SimpleImputer(strategy='mean').fit_transform(X_val)

# Train decision tree
model = DecisionTreeClassifier(max_depth=3, random_state=42)
model.fit(X_train, y_train)

# Plot tree
plt.figure(figsize=(15, 8))
plot_tree(model, feature_names=X.columns, class_names=['Not Survived', 'Survived'], filled=True, rounded=True)
plt.show()

# %% [markdown]
# # Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score
#
# # Importing classification report and confusion matrix from sklearn metrics
#
# # Making predictions
#
# # Printing classification report

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Make predictions
y_pred = model.predict(X_validation)

# Print Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_validation, y_pred))

# Print Accuracy
print(f"Accuracy: {accuracy_score(y_validation, y_pred):.2f}")

# Print Classification Report (Precision, Recall, F1-score)
print("\nClassification Report:\n", classification_report(y_validation, y_pred))
# Out:
# Confusion Matrix:
#  [[45  9]
#  [ 8 28]]
# Accuracy: 0.81
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84        54
#            1       0.76      0.78      0.77        36
#
#     accuracy                           0.81        90
#    macro avg       0.80      0.81      0.80        90
# weighted avg       0.81      0.81      0.81        90

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
y_pred = model.predict(X_validation)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_validation, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84        54
#            1       0.76      0.78      0.77        36
#
#     accuracy                           0.81        90
#    macro avg       0.80      0.81      0.80        90
# weighted avg       0.81      0.81      0.81        90

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Make predictions
y_pred = model.predict(X_val)

# Print confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_val, y_pred))

# Print accuracy
print(f"Accuracy: {accuracy_score(y_val, y_pred):.2f}")

# Print classification report (includes Precision, Recall, F1-score)
print("\nClassification Report:")
print(classification_report(y_val, y_pred))
# Out:
# Confusion Matrix:
# [[46  8]
#  [ 8 28]]
# Accuracy: 0.82
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85        54
#            1       0.78      0.78      0.78        36
#
#     accuracy                           0.82        90
#    macro avg       0.81      0.81      0.81        90
# weighted avg       0.82      0.82      0.82        90

# %% [markdown]
# # Printing confusion matrix and accuracy

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# Print confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_validation, y_pred))

# Print accuracy
print(f"Accuracy: {accuracy_score(y_validation, y_pred):.2f}")
# Out:
# Confusion Matrix:
# [[46  8]
#  [ 8 28]]
# Accuracy: 0.82
